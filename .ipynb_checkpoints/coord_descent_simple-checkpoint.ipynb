# %%
#differentiation in python is interesting, may have to to sympy or theano, see https://stackoverflow.com/questions/9876290/how-do-i-compute-derivative-using-numpy
import sympy as syp
import numpy as np
import matplotlib.pyplot as plt

# %%
variables='x y'
symbs = syp.symbols(variables)
z=symbs[0]**2+symbs[0]*symbs[1]+symbs[1]**2  #x**2+xy+y**2

# %%
f = syp.lambdify(symbs, z, 'numpy')
f([1,2],-1)

#one keeps a coordinate constant, they derives with respect to the coordinate of interest and makes it equal to zero, then solve for coordinate of interest. This is the minimum at the given constant coord
#the previous coordinate of interest is then kept constant and the other coord is derived and solved for. The process iterates untill convergence.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-3dc1621b6ad6> in <module>
#       1 f = syp.lambdify(symbs, z, 'numpy')
# ----> 2 f([1,2],-1)
#       3
#       4 #one keeps a coordinate constant, they derives with respect to the coordinate of interest and makes it equal to zero, then solve for coordinate of interest. This is the minimum at the given constant coord
#       5 #the previous coordinate of interest is then kept constant and the other coord is derived and solved for. The process iterates untill convergence.
#
# <lambdifygenerated-3> in _lambdifygenerated(x, y)
#       1 def _lambdifygenerated(x, y):
# ----> 2     return (x**2 + x*y + y**2)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'

# %%
haar=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])
#print(haar)
y=np.array([[2],[3]])
y=y/np.sqrt(y[0]**2+y[1]**2)

z=haar@y

print(y)
print(z)
print(y.T@y)
print(z.T@z)

print(testv_haar.T@testv)
print(testv.T@testv_haar)
#print(np.inner(testv.flatten(),testv_haar.flatten()))
#print(testv.shape,testv_haar.shape)
#np.linalg.inv(haar)
def unsamp_haar(z2,y1): #undersample haar wavelet transform
    return z2+(2*np.sqrt(2)*y1)
y1=2    

z1=np.linspace(-6,6)
z2=np.linspace(-6,6)
z1=unsamp_haar(z2,y1)
plt.plot(z1,intens)
plt.show()
plt.plot(z2,intens)

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

#X, Y = np.meshgrid(x, y)
#Z = unsamp_haar(X, Y,2)
#fig = plt.figure()
#ax = plt.axes(projection='3d')
#ax.contour3D(X, Y, Z, 100)
#ax.set_xlabel('x')
#ax.set_ylabel('y')
#ax.set_zlabel('z');
#ax.view_init(60, 35)
#print(sum(testv[:]*testv_haar[:]))
# Out:
# [[0.5547002 ]
#  [0.83205029]]
# [[ 0.98058068]
#  [-0.19611614]]
# [[1.]]
# [[1.]]
# [[0.38074981]]
# [[0.38074981]]
